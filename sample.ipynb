# %%
import matplotlib.pyplot as plt
import matplotlib
import math
import numpy as np

# %% [markdown]
# sample 1

# %%
f = [40, 60, 100, 200, 400, 500, 600, 1000, 2000, 3500, 4000, 5000, 6000, 8000, 9000, 10000, 11000, 12000, 15000]
val = [0.17782794100389226, 0.08912509381337455, 0.04466835921509631, 0.01, 0.00630957344480193, 0.0031622776601683794, 0.00223872113856834, 0.0012589254117941675, 0.0007943282347242813, 0.0005011872336272725, 0.00015848931924611142, 0.0001778279410038923, 0.00031622776601683794, 0.0007943282347242813, 0.001584893192461114, 0.0017782794100389228, 0.0014125375446227542, 0.0017782794100389228, 0.01412537544622754]
fi = list(range(len(f)))
db = [ (20*math.log(x, 10)) for x in val]
print(db)
# Out:
# [-15.0, -21.0, -26.999999999999996, -39.99999999999999, -43.99999999999999, -50.0, -52.999999999999986, -57.999999999999986, -62.0, -65.99999999999999, -75.99999999999999, -74.99999999999999, -70.0, -62.0, -56.0, -55.0, -56.99999999999999, -55.0, -37.0]

# %% [markdown]
# sample 2

# %%
f2 = [40, 60, 100, 200, 400, 500, 600, 1000, 2000, 3500, 4000, 5000, 6000, 8000, 9000, 10000, 11000, 12000, 15000]
val2 = [0.07943282347242814, 0.04466835921509631, 0.01412537544622754, 0.007943282347242814, 0.0031622776601683794, 0.003981071705534973, 0.0017782794100389228, 0.0008912509381337459, 0.0005623413251903491, 0.00031622776601683794, 0.00025118864315095795, 0.00019952623149688788, 0.000050118723362727245, 0.0001122018454301963, 0.00007943282347242821, 0.000223872113856834, 0.00015848931924611142, 0.00025118864315095795, 0.0008912509381337459]
fi2 = list(range(len(f2)))
db2 = [ (20*math.log(x, 10)) for x in val2]
print(db2)
# Out:
# [-21.999999999999996, -26.999999999999996, -37.0, -42.0, -50.0, -48.0, -55.0, -60.999999999999986, -64.99999999999999, -70.0, -71.99999999999999, -74.0, -86.0, -78.99999999999999, -82.0, -73.0, -75.99999999999999, -71.99999999999999, -60.999999999999986]

# %%
db3 = [-39, -39, -42, -48, -54, -60, -66, -66, -72, -75, -78, -78, -75, -69, -72, -63, -66, -63, -51]

# %%
fig, axl = plt.subplots(nrows=1, ncols=1,figsize=(6, 5))
# ax.plot(f,db)
# ax.plot(f2,db2)
# ax.set_xscale("log")
# ax.set_xticks([100, 1000, 3500, 10000])
# ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

axl.plot(f,db)
axl.plot(f2,db2)
axl.plot(f, db3)
axl.set_xscale("log")
axl.set_xticks([100, 1000, 3500, 10000])
axl.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

# ax.errorbar(f, db, yerr=3)
# ax.errorbar(f2, db2, yerr=3)
